# %% [markdown]
# This file is just for generating the tableNames.py file so that we can have a list of all the tables for autocompletion.

# %%
import xml.etree.ElementTree as ET
import os
import glob
import re

# Read an xml file to get table name and id
def getTableNameID(filePath: str) -> str:
    tree = ET.parse(filePath)
    root = tree.getroot()
    tableName = root.find("./ContentClassification/TableName").text
    tableId = root.find("./ContentClassification/TableIdentity").text
    return tableName + " - t" + tableId

files = [file for file in glob.glob('./pymort/archive_2021_Oct_17_051924/*') if file.endswith('.xml')]
# I just use this for debugging, make a smaller slice to reduce time
shortenedList = files[:100]

# Combine TableName and TableID into single string
tablesNamesIDs = [getTableNameID(filePath) for filePath in shortenedList]
# Sort by the Table ID, the numbers at the end of the string
tablesNamesIDs.sort(key=lambda x: int(re.findall(r'\d+$', x)[0]))
# Format names into their own lines with commas and quotes for writing to the file.
commaSeparatedTableNames = "\n"+", \n".join(['"' + nameID + '"' for nameID in tablesNamesIDs])+"\n"
# Include table names and IDs as a Literal type to provide autocompletion
writtenFile = "from typing import Literal\n\n" + f"TableName = Literal[{commaSeparatedTableNames}]"

# write lit to file
with open("tableNames.py", "w") as f:
  f.write(writtenFile)
# Out:
# from typing import Literal
#
# TableName = Literal[
# "1941 CSO Basic Table, ANB - t1",
# "1975 Modern CSO – Male, ANB - t16",
# "1980 CSO - Table SC (60% Male Blend - Smoker), ALB - t117",
# "AF80 - t261",
# "American Men Table with Bowerman’s Extension, ANB - t301",
# "US Life Tables 1969-71 – White Males, ANB - t513",
# "ELT No.12 (1960-62) – Male, ANB - t659",
# "1970-75 ADB Experience by Amount of Claims Paid, ANB - t705",
# "1968-72 CIA Group Life ADB – Males, ANB - t711",
# "IM80 - t842",
# "Table 4: 1944 RRB Railway Disabled Annuitants Mortality Table, ALB - t856",
# "1994 Variable Annuity MGDB Mortality Table – Male, ANB - t881",
# "1987-91 U.P.E.A. -  Male  - t895",
# "a(55) Projection Scale for Annuitants - t922",
# "2008 VBT-Primary Male Non-Smoker ALB - t1002",
# "2008 VBT Female RR140 Non-Smoker ALB - t1016",
# "1985 CIDA Termination Rates, Male, Occ Cl 1, Acc and Sick, 60 day EP - t1162",
# "1985 CIDA Termination Rates, Male, Occ Cl 2, Accident Only, 0 day EP - t1176",
# "1985 CIDA Termination Rates, Female, Occ Cl 2, Acc & Sick, 60 day EP - t1189",
# "1985 CIDA Termination Rates, Male, Occ Cl 3, Acc & Sick, 182 day EP - t1200",
# "1985 CIDA Termination Rates, Male, Occ Cl 3, Acc & Sick, 365 day EP - t1201",
# "1985 CIDA Termination Rates, Male, Occ Cl 4, Acc & Sick, 14 day EP - t1214",
# "1985 CIDA Termination Rates, Male, Occ Cl 4, Acc & Sick, 30 day EP - t1215",
# "1985 CIDA Termination Rates, Female, Occ Cl 4, Acc & Sick, 365 day EP - t1228",
# "1985 CIDA Termination Rates, Female, Occ Cl 4, Acc & Sick, 730 day EP - t1229",
# "1985 CIDA Incidence Rates - Male, Occ Cl 3, Acc Only, 91 day EP - t1348",
# "1985 CIDA Incidence Rates - Female, Occ Cl 3, Acc Only, 0 day EP - t1360",
# "1985 CIDA Incidence Rates - Female, Occ Cl 3, Acc Only, 91 day EP - t1374",
# "1985 CIDA Incidence Rates, Male, Occ Cl 4, Acc Only, 365 day EP - t1406",
# "1985 CIDA Incidence Rates, Female, Occ Cl 4, Acc Only, 0 day EP - t1412",
# "RP-2000  Mortality Table - Female Aggregate  - Disabled Retiree - t1599",
# "1869 Twenty Offices H^F – Female, ANB - t1604",
# "1965-70 Modified Basic Table - Female, ANB - t1610",
# "2005-2007 Individual Life Persistency Study – Whole Life, Non-smoker - t1638",
# "2012 IDEC Claim Incidence Table - Male, Occ Class 1, Sick, 720 day EP - t1758",
# "2012 IDEC Claim Incidence Table - Male, Occ Class 2, Sick, 180 day EP - t1764",
# "2012 IDEC Claim Incidence Table - Male, Occ Class 3, Sick, 60 day EP - t1770",
# "2012 IDEC Claim Incidence Table - Female, Occ Class 4, Acc, 90 day EP - t1823",
# "2012 IDEC Claim Incidence Table - Female, Occ Class 1, Sick, 14 day EP - t1837",
# "Canadian Life Table 1955-57 - Males, ANB - t2046",
# "Canadian Life Table 1955-57 - Females, ANB - t2047",
# "Canadian Life Table 1990-92 - Females, ANB - t2053",
# "2005-2007 Individual Life Persistency Study – YRT Insurance on an Attained Age Basis - t2084",
# "2005-2007 Individual Life Persistency Study – Females 10 YLT - t2090",
# "1983 GAM - Table E (40% Male Blend), ANB - t2127",
# "2001-2002 Individual Life Persistency Study – Whole Life, Females - t2133",
# "2003-2004 Individual Life Persistency Study – 10 YLT, Issue Ages 50-59 - t2245",
# "2003-2004 Individual Life Persistency Study – 20 YLT, Issue Ages 60-69 - t2251",
# "2003-2004 Individual Life Persistency Study – YRT, Monthly Premiums - t2279",
# "2003-2004 Individual Life Persistency Study – UL, Issue Ages Under 20 - t2286",
# "2003-2004 Individual Life Persistency Study – UL, Issue Ages 70 and Older - t2292",
# "AMC00 - t2319",
# "TMC00 - t2325",
# "IML00 - t2331",
# "2004-2005 Individual Life Persistency Study – 20 YLT Issue Ages 50-59 - t2443",
# "2004-2005 Individual Life Persistency Study – YRT Smokers - t2457",
# "2004-2005 U.S. Individual Life Persistency Study – Universal Life Issue Ages 20-29 - t2480",
# "2004-2005 U.S. Individual Life Persistency Study – Universal Life Non-medical Underwriting - t2494",
# "S9702 – Male, ANB - t2523",
# "2005-2007 LTC Persistency Study - Males - t2537",
# "2012 IDEC Select Termination Rates - Male, Occ Cl 1, Acc and Sick, 30 day EP - t2641",
# "2012 IDEC Select Termination Rates - Male, Occ Cl 2, Acc and Sick, 90 day EP - t2655",
# "2012 IDEC Select Termination Rates - Female, Occ Cl 3, Acc and Sick, 7 day EP - t2669",
# "2012 IDEC Select Termination Rates - Female, Occ Cl 4, Acc and Sick, 14 day EP - t2682",
# "EMSSAH97 - t2696",
# "TFV 00-02 - t2708",
# "THV 00-02 - t2709",
# "ELT No. 7 (1901-1911) - Male - t2721",
# "1901-1910 Sweden – Male - t2735",
# "AVÖ - 1996 R Gruppen - Frauen - t2866",
# "Tablica Trwania Życia 2008 - Płci żeńskiej   - t2872",
# "Sterbetafel 1980/82 - Männlich - t2899",
# "EAE 2005 K - Females - t2906",
# "Tablica Trwania Życia 2012 - OGÓŁEM - t2912",
# "2007-2011 Israel – Female Arabs, ANB - t3013",
# "IRS 2010 Static Mortality Tables - t3167",
# "IRS 2010 Static Mortality Tables - t3173",
# "IRS 2014 Static Mortality Tables - t3198",
# "IRS 2015 Static Mortality Tables - t3205",
# "2015 VBT Female Non-Smoker RR70 ALB - t3211",
# "2015 VBT Male Non-Smoker RR70 ALB - t3239",
# "2017 Unloaded CSO Preferred Structure Smoker Residual Standard Male ALB - t3358",
# "2017 Unloaded CSO Preferred Structure Smoker Preferred Female ALB - t3359",
# "2017 Unloaded CSO Composite Female ALB - t3364",
# "2017 Unloaded CSO Smoker Distinct Nonsmoker Male ANB  - t3365",
# "2017 Unloaded CSO Smoker Distinct Nonsmoker Female ALB  - t3370",
# "2017 Unloaded CSO Smoker Distinct Smoker Male ALB  - t3371",
# "PubNS-2010 Male Disabled Retiree - t3402",
# "Pub-2010 Female Contingent Survivor - t3403",
# "PubS-2010(B) Male Employee - t3416",
# "PubS-2010(A) Female Retiree - t3417",
# "Pri-2012 Female Nondisabled Annuitant White Collar - t3563",
# "Pri.H-2012 Female Employee Top Quartile - t3577",
# "Pri.H-2012 Male Employee White Collar - t3588",
# "1975-80 Mortality Tables with Manulife Extensions - Male, Age Nearest Birthday - t3601",
# "Chile Abridged Life Tables 1995-2000 Hombres - t23022",
# "TM_1889_1900_M - t34006",
# "TM_1920_21_M - t34012",
# "1974 TSO Experience Table (1st) - t50027",
# "1996 Japan All Company, Female - t50033"
# ]

# %%
import pymort

table = pymort.load("2017 Loaded CSO Composite Gender-Blended 20% Male ALB - t3282")
table.rates(0)
# Out:
# <module 'pymort.SOA_Tables_20210915' from '/Users/matthewcaseres/Documents/Python/pymort/pymort/SOA_Tables_20210915/__init__.py'>
# [0.00026,
#  0.00014,
#  0.0001,
#  9e-05,
#  9e-05,
#  9e-05,
#  9e-05,
#  8e-05,
#  8e-05,
#  8e-05,
#  9e-05,
#  9e-05,
#  9e-05,
#  0.00011,
#  0.00018,
#  0.00027,
#  0.00036,
#  0.00042,
#  0.00042,
#  0.00043,
#  0.00043,
#  0.00044,
#  0.00045,
#  0.00048,
#  0.00052,
#  0.00052,
#  0.00053,
#  0.00053,
#  0.00054,
#  0.00056,
#  0.00059,
#  0.00063,
#  0.00068,
#  0.00074,
#  0.00081,
#  0.0009,
#  0.001,
#  0.0011,
#  0.0012,
#  0.00128,
#  0.00136,
#  0.00143,
#  0.00149,
#  0.00154,
#  0.00159,
#  0.00167,
#  0.00177,
#  0.00188,
#  0.00199,
#  0.00213,
#  0.00229,
#  0.00246,
#  0.00266,
#  0.00289,
#  0.00314,
#  0.00342,
#  0.00374,
#  0.0041,
#  0.0045,
#  0.00496,
#  0.00549,
#  0.00608,
#  0.00676,
#  0.00751,
#  0.00834,
#  0.00925,
#  0.01026,
#  0.01137,
#  0.01259,
#  0.01395,
#  0.01545,
#  0.01712,
#  0.01897,
#  0.02105,
#  0.02337,
#  0.02596,
#  0.02887,
#  0.03211,
#  0.03574,
#  0.03985,
#  0.04461,
#  0.05013,
#  0.05643,
#  0.0637,
#  0.07202,
#  0.08154,
#  0.0922,
#  0.1039,
#  0.11671,
#  0.13054,
#  0.14515,
#  0.16039,
#  0.17636,
#  0.19249,
#  0.20858,
#  0.22668,
#  0.24779,
#  0.2706,
#  0.29496,
#  0.32047,
#  0.34592,
#  0.37042,
#  0.39453,
#  0.41785,
#  0.43998,
#  0.46053,
#  0.48213,
#  0.50829,
#  0.53584,
#  0.56485,
#  0.59538,
#  0.62751,
#  0.66131,
#  0.69686,
#  0.73421,
#  0.77346,
#  0.81466,
#  0.85788,
#  0.90315,
#  0.95053,
#  1.0]
